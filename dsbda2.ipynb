# %%
import pandas as pd
import numpy as np
import os

os.chdir("C:\\Users\\Vikas\\Downloads")
air = pd.read_csv("air_quality.csv")
heart = pd.read_csv("heart.csv")

# %%
# Data Cleaning

air.colums=air.columns.str.strip()
heart.colums=heart.columns.str.strip()

air=air.dropna()
heart=heart.fillna(heart.mean(numeric_only=True))

air=air.drop_duplicates()
heart=heart.drop_duplicates()
# Out:
# C:\Users\vikas\AppData\Local\Temp\ipykernel_13692\1124539665.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   air.colums=air.columns.str.strip()

# %%
# Data Intergraion 

if isinstance(air.columns,pd.MultiIndex):
    air.columns=air.columns.get_level_values(0)

if isinstance(heart.columns,pd.MultiIndex):
    heart.columns=heart.colums.get_level_columns(0)

air=air.reset_index(drop=True)
heart=heart.reset_index(drop=True)

data=pd.concat([air,heart],axis=1)

print(data.head())
# Out:
#   Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;  \
# 0                                             7578;;
# 1                                             7502;;
# 2                                             7867;;
# 3                                             7888;;
# 4                                             7848;;
#
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  52.0  1.0  0.0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1  53.0  1.0  0.0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2  70.0  1.0  0.0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3  61.0  1.0  0.0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4  62.0  0.0  0.0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
#
#    slope   ca  thal  target
# 0    2.0  2.0   3.0     0.0
# 1    0.0  0.0   3.0     0.0
# 2    0.0  0.0   3.0     0.0
# 3    2.0  1.0   3.0     0.0
# 4    1.0  3.0   2.0     0.0

# %%
# data Tranformation
if 'PM2.5' in data.columns:
    data['PM2.5']=(data['PM2.5']-data['PM2.5'].min()) / \
    (data['PM2.5'].max()-data['PM2.5'].min())
data=pd.get_dummies(data,drop_first=True)

data
# Out:
#        age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52.0  1.0  0.0     125.0  212.0  0.0      1.0    168.0    0.0      1.0
# 1     53.0  1.0  0.0     140.0  203.0  1.0      0.0    155.0    1.0      3.1
# 2     70.0  1.0  0.0     145.0  174.0  0.0      1.0    125.0    1.0      2.6
# 3     61.0  1.0  0.0     148.0  203.0  0.0      1.0    161.0    0.0      0.0
# 4     62.0  0.0  0.0     138.0  294.0  1.0      1.0    106.0    0.0      1.9
# ...    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 4936   NaN  NaN  NaN       NaN    NaN  NaN      NaN      NaN    NaN      NaN
# 4937   NaN  NaN  NaN       NaN    NaN  NaN      NaN      NaN    NaN      NaN
# 4938   NaN  NaN  NaN       NaN    NaN  NaN      NaN      NaN    NaN      NaN
# 4939   NaN  NaN  NaN       NaN    NaN  NaN      NaN      NaN    NaN      NaN
# 4940   NaN  NaN  NaN       NaN    NaN  NaN      NaN      NaN    NaN      NaN
#
#       ...  \
# 0     ...
# 1     ...
# 2     ...
# 3     ...
# 4     ...
# ...   ...
# 4936  ...
# 4937  ...
# 4938  ...
# 4939  ...
# 4940  ...
#
#       Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;_9978;;  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 4936                                              False
# 4937                                              False
# 4938                                              False
# 4939                                              False
# 4940                                              False
#
#       Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;_9979;;  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 4936                                              False
# 4937                                              False
# 4938                                              False
# 4939                                              False
# 4940                                              False
#
#       Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;_9981;;  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 4936                                              False
# 4937                                              False
# 4938                                              False
# 4939                                              False
# 4940                                              False
#
#       Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;_9982;;  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 4936                                              False
# 4937                                              False
# 4938                                              False
# 4939                                              False
# 4940                                              False
#
#       Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;_9983;;  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 4936                                              False
# 4937                                              False
# 4938                                              False
# 4939                                              False
# 4940                                              False
#
#       Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;_9986;;  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 4936                                              False
# 4937                                              False
# 4938                                              False
# 4939                                              False
# 4940                                              False
#
#       Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;_9989;;  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 4936                                              False
# 4937                                              False
# 4938                                              False
# 4939                                              False
# 4940                                              False
#
#       Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;_9990;;  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 4936                                              False
# 4937                                              False
# 4938                                              False
# 4939                                              False
# 4940                                              False
#
#       Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;_9993;;  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 4936                                              False
# 4937                                              False
# 4938                                              False
# 4939                                              False
# 4940                                              False
#
#       Date;Time;CO(GT);PT08.S1(CO);NMHC(GT);C6H6(GT);PT08.S2(NMHC);NOx(GT);PT08.S3(NOx);NO2(GT);PT08.S4(NO2);PT08.S5(O3);T;RH;AH;;_9998;;
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 4936                                              False
# 4937                                              False
# 4938                                              False
# 4939                                              False
# 4940                                              False
#
# [4941 rows x 4954 columns]

# %%
# Error Handling
data.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# std      0.526027   22.903527    0.470196    1.161452    0.616274    1.006748
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.250000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  152.500000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  302.000000  302.000000
# mean     2.314570    0.543046
# std      0.613026    0.498970
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
for col in data.select_dtypes(include=np.number).columns:
    data[col]=data[col].apply(lambda x:abs(x))

if 'age' in data.columns:
    data=data[data['age']<=100]
data.describe()
# Out:
# C:\Users\vikas\AppData\Local\Temp\ipykernel_13692\1774318740.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[col]=data[col].apply(lambda x:abs(x))
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# std      0.526027   22.903527    0.470196    1.161452    0.616274    1.006748
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.250000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  152.500000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  302.000000  302.000000
# mean     2.314570    0.543046
# std      0.613026    0.498970
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Assume target column exists
if 'target' in data.columns:
    X = data.drop('target', axis=1)
    y = data['target']

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

    model = LogisticRegression(max_iter=1000)
    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    print("\nModel Accuracy:")
    print(accuracy_score(y_test, y_pred))
# Out:
# Model Accuracy:
# 0.819672131147541
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
